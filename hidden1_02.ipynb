# %%
###########################

# Problema de clasificación:
# y: arriba o abajo de la mediana del precio de la vivienda

# %%
# Librerías
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv('dataset.csv')

# %%
dataset.head(20)
# Out:
#     LotArea  OverallQual  OverallCond  TotalBsmtSF  FullBath  HalfBath  \
# 0      8450            7            5          856         2         1
# 1      9600            6            8         1262         2         0
# 2     11250            7            5          920         2         1
# 3      9550            7            5          756         1         0
# 4     14260            8            5         1145         2         1
# 5     14115            5            5          796         1         1
# 6     10084            8            5         1686         2         0
# 7     10382            7            6         1107         2         1
# 8      6120            7            5          952         2         0
# 9      7420            5            6          991         1         0
# 10    11200            5            5         1040         1         0
# 11    11924            9            5         1175         3         0
# 12    12968            5            6          912         1         0
# 13    10652            7            5         1494         2         0
# 14    10920            6            5         1253         1         1
# 15     6120            7            8          832         1         0
# 16    11241            6            7         1004         1         0
# 17    10791            4            5            0         2         0
# 18    13695            5            5         1114         1         1
# 19     7560            5            6         1029         1         0
#
#     BedroomAbvGr  TotRmsAbvGrd  Fireplaces  GarageArea  AboveMedianPrice
# 0              3             8           0         548                 1
# 1              3             6           1         460                 1
# 2              3             6           1         608                 1
# 3              3             7           1         642                 0
# 4              4             9           1         836                 1
# 5              1             5           0         480                 0
# 6              3             7           1         636                 1
# 7              3             7           2         484                 1
# 8              2             8           2         468                 0
# 9              2             5           2         205                 0
# 10             3             5           0         384                 0
# 11             4            11           2         736                 1
# 12             2             4           0         352                 0
# 13             3             7           1         840                 1
# 14             2             5           1         352                 0
# 15             2             5           0         576                 0
# 16             2             5           1         480                 0
# 17             2             6           0         516                 0
# 18             3             6           0         576                 0
# 19             3             6           0         294                 0

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   LotArea           1460 non-null   int64
#  1   OverallQual       1460 non-null   int64
#  2   OverallCond       1460 non-null   int64
#  3   TotalBsmtSF       1460 non-null   int64
#  4   FullBath          1460 non-null   int64
#  5   HalfBath          1460 non-null   int64
#  6   BedroomAbvGr      1460 non-null   int64
#  7   TotRmsAbvGrd      1460 non-null   int64
#  8   Fireplaces        1460 non-null   int64
#  9   GarageArea        1460 non-null   int64
#  10  AboveMedianPrice  1460 non-null   int64
# dtypes: int64(11)
# memory usage: 125.6 KB

# %%
# Seleccionar variables independientes y variables dependientes
X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, -1].values

# %%
X[:10]
# Out:
# array([[ 8450,     7,     5,   856,     2,     1,     3,     8,     0,
#           548],
#        [ 9600,     6,     8,  1262,     2,     0,     3,     6,     1,
#           460],
#        [11250,     7,     5,   920,     2,     1,     3,     6,     1,
#           608],
#        [ 9550,     7,     5,   756,     1,     0,     3,     7,     1,
#           642],
#        [14260,     8,     5,  1145,     2,     1,     4,     9,     1,
#           836],
#        [14115,     5,     5,   796,     1,     1,     1,     5,     0,
#           480],
#        [10084,     8,     5,  1686,     2,     0,     3,     7,     1,
#           636],
#        [10382,     7,     6,  1107,     2,     1,     3,     7,     2,
#           484],
#        [ 6120,     7,     5,   952,     2,     0,     2,     8,     2,
#           468],
#        [ 7420,     5,     6,   991,     1,     0,     2,     5,     2,
#           205]])

# %%
# como no hay variables categóricas no hace falta transformas ningún dato a variable ficticia.

# %%
# Dividir el dataset en train y test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
# Escalamos las características, aunque no hay mucha diferencia entre los números pero es una buena práctica
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
import keras
# Out:
# Using TensorFlow backend.

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout

# %%
modelRedNeuronalClasificacion = Sequential()

# %%
# Creamos la capa de entrada y la primer capa hidden en un mismo paso.

# Entrada de la red: 10 características.
input_size = 10

# Tamaño de la capa hidden.
# para el tamaño no hay una regla, se suele tomar el promedio entre la entrada (10) y la salida (1)
hidden_layer_size = 5

# init='uniform' pesos iniciales aleatorios uniformes.
modelRedNeuronalClasificacion.add(Dense(input_dim=input_size, units=hidden_layer_size,kernel_initializer='uniform', activation='relu'))

# %%
# Agregamos una capa Dropout a la primer capa hidden
modelRedNeuronalClasificacion.add(Dropout(rate=0.1))

# %%
# Capa de salida

# Salida de la red: 1 salida, activación sigmoid.
# Activacion sigmoidal ya que la variable dependiente y es una sola categoria, 1 o 0.
output_size = 1
modelRedNeuronalClasificacion.add(Dense(units=output_size,kernel_initializer='uniform', activation='sigmoid'))

# %%
# Compilar la red neuronal
# binary_crossentropy para sigmoid, categorical_crossentropy para softmax (binary_crossentropy en este caso)
# optimizador = adam. Puede ser rmsprop u otros algoritmos.
modelRedNeuronalClasificacion.compile(optimizer='adam', loss='binary_crossentropy', metrics=['acc'])

# %%
# Entrenamiento de la red.
# Tamaño del Batch: observaciones a incluir en el cálculo de la pérdida antes de actualizar los pesos. No hay una regla.
# Epochs: Pasadas completas por todo el dataset.

batch_size = 25
max_epochs = 100

history = modelRedNeuronalClasificacion.fit(X_train, y_train,
            batch_size=batch_size,
            epochs=max_epochs,
            validation_data=(X_test, y_test))
# Out:
# Train on 1168 samples, validate on 292 samples
# Epoch 1/100
# 1168/1168 [==============================] - 0s 314us/step - loss: 0.6898 - acc: 0.7363 - val_loss: 0.6807 - val_acc: 0.8801
# Epoch 2/100
# 1168/1168 [==============================] - 0s 104us/step - loss: 0.6589 - acc: 0.8656 - val_loss: 0.6272 - val_acc: 0.9041
# Epoch 3/100
# 1168/1168 [==============================] - 0s 106us/step - loss: 0.5899 - acc: 0.8673 - val_loss: 0.5447 - val_acc: 0.9041
# Epoch 4/100
# 1168/1168 [==============================] - 0s 120us/step - loss: 0.5082 - acc: 0.8664 - val_loss: 0.4641 - val_acc: 0.9041
# Epoch 5/100
# 1168/1168 [==============================] - 0s 122us/step - loss: 0.4375 - acc: 0.8784 - val_loss: 0.4022 - val_acc: 0.9075
# Epoch 6/100
# 1168/1168 [==============================] - 0s 114us/step - loss: 0.3840 - acc: 0.8767 - val_loss: 0.3592 - val_acc: 0.9075
# Epoch 7/100
# 1168/1168 [==============================] - 0s 114us/step - loss: 0.3511 - acc: 0.8853 - val_loss: 0.3302 - val_acc: 0.9178
# Epoch 8/100
# 1168/1168 [==============================] - 0s 104us/step - loss: 0.3202 - acc: 0.8870 - val_loss: 0.3106 - val_acc: 0.9212
# Epoch 9/100
# 1168/1168 [==============================] - 0s 109us/step - loss: 0.3018 - acc: 0.8878 - val_loss: 0.2974 - val_acc: 0.9247
# Epoch 10/100
# 1168/1168 [==============================] - 0s 110us/step - loss: 0.2882 - acc: 0.8861 - val_loss: 0.2886 - val_acc: 0.9247
# Epoch 11/100
# 1168/1168 [==============================] - 0s 99us/step - loss: 0.2814 - acc: 0.8870 - val_loss: 0.2833 - val_acc: 0.9247
# Epoch 12/100
# 1168/1168 [==============================] - 0s 115us/step - loss: 0.2693 - acc: 0.8921 - val_loss: 0.2794 - val_acc: 0.9247
# Epoch 13/100
# 1168/1168 [==============================] - 0s 105us/step - loss: 0.2672 - acc: 0.8896 - val_loss: 0.2761 - val_acc: 0.9212
# Epoch 14/100
# 1168/1168 [==============================] - 0s 106us/step - loss: 0.2622 - acc: 0.8887 - val_loss: 0.2733 - val_acc: 0.9247
# Epoch 15/100
# 1168/1168 [==============================] - 0s 114us/step - loss: 0.2572 - acc: 0.8921 - val_loss: 0.2727 - val_acc: 0.9247
# Epoch 16/100
# 1168/1168 [==============================] - 0s 105us/step - loss: 0.2527 - acc: 0.8904 - val_loss: 0.2720 - val_acc: 0.9247
# Epoch 17/100
# 1168/1168 [==============================] - 0s 117us/step - loss: 0.2441 - acc: 0.8913 - val_loss: 0.2713 - val_acc: 0.9247
# Epoch 18/100
# 1168/1168 [==============================] - 0s 108us/step - loss: 0.2491 - acc: 0.8861 - val_loss: 0.2709 - val_acc: 0.9212
# Epoch 19/100
# 1168/1168 [==============================] - 0s 122us/step - loss: 0.2489 - acc: 0.8887 - val_loss: 0.2713 - val_acc: 0.9212
# Epoch 20/100
# 1168/1168 [==============================] - 0s 100us/step - loss: 0.2485 - acc: 0.8896 - val_loss: 0.2708 - val_acc: 0.9212
# Epoch 21/100
# 1168/1168 [==============================] - 0s 122us/step - loss: 0.2480 - acc: 0.8887 - val_loss: 0.2715 - val_acc: 0.9212
# Epoch 22/100
# 1168/1168 [==============================] - 0s 112us/step - loss: 0.2493 - acc: 0.8870 - val_loss: 0.2712 - val_acc: 0.9247
# Epoch 23/100
# 1168/1168 [==============================] - 0s 100us/step - loss: 0.2408 - acc: 0.8913 - val_loss: 0.2713 - val_acc: 0.9212
# Epoch 24/100
# 1168/1168 [==============================] - 0s 107us/step - loss: 0.2380 - acc: 0.8990 - val_loss: 0.2714 - val_acc: 0.9212
# Epoch 25/100
# 1168/1168 [==============================] - 0s 110us/step - loss: 0.2348 - acc: 0.8904 - val_loss: 0.2731 - val_acc: 0.9212
# Epoch 26/100
# 1168/1168 [==============================] - 0s 111us/step - loss: 0.2410 - acc: 0.8938 - val_loss: 0.2732 - val_acc: 0.9212
# Epoch 27/100
# 1168/1168 [==============================] - 0s 112us/step - loss: 0.2353 - acc: 0.8878 - val_loss: 0.2745 - val_acc: 0.9212
# Epoch 28/100
# 1168/1168 [==============================] - 0s 140us/step - loss: 0.2400 - acc: 0.8930 - val_loss: 0.2754 - val_acc: 0.9212
# Epoch 29/100
# 1168/1168 [==============================] - 0s 113us/step - loss: 0.2387 - acc: 0.8930 - val_loss: 0.2755 - val_acc: 0.9212
# Epoch 30/100
# 1168/1168 [==============================] - 0s 99us/step - loss: 0.2420 - acc: 0.8913 - val_loss: 0.2751 - val_acc: 0.9212
# Epoch 31/100
# 1168/1168 [==============================] - 0s 113us/step - loss: 0.2375 - acc: 0.8896 - val_loss: 0.2762 - val_acc: 0.9212
# Epoch 32/100
# 1168/1168 [==============================] - 0s 113us/step - loss: 0.2393 - acc: 0.8870 - val_loss: 0.2763 - val_acc: 0.9212
# Epoch 33/100
# 1168/1168 [==============================] - 0s 101us/step - loss: 0.2371 - acc: 0.8921 - val_loss: 0.2774 - val_acc: 0.9212
# Epoch 34/100
# 1168/1168 [==============================] - 0s 111us/step - loss: 0.2383 - acc: 0.8921 - val_loss: 0.2783 - val_acc: 0.9212
# Epoch 35/100
# 1168/1168 [==============================] - 0s 119us/step - loss: 0.2395 - acc: 0.8921 - val_loss: 0.2790 - val_acc: 0.9178
# Epoch 36/100
# 1168/1168 [==============================] - 0s 103us/step - loss: 0.2387 - acc: 0.8878 - val_loss: 0.2789 - val_acc: 0.9178
# Epoch 37/100
# 1168/1168 [==============================] - 0s 113us/step - loss: 0.2330 - acc: 0.8964 - val_loss: 0.2797 - val_acc: 0.9178
# Epoch 38/100
# 1168/1168 [==============================] - 0s 103us/step - loss: 0.2374 - acc: 0.8870 - val_loss: 0.2808 - val_acc: 0.9178
# Epoch 39/100
# 1168/1168 [==============================] - 0s 104us/step - loss: 0.2406 - acc: 0.8887 - val_loss: 0.2808 - val_acc: 0.9178
# Epoch 40/100
# 1168/1168 [==============================] - 0s 103us/step - loss: 0.2349 - acc: 0.8921 - val_loss: 0.2815 - val_acc: 0.9178
# Epoch 41/100
# 1168/1168 [==============================] - 0s 100us/step - loss: 0.2325 - acc: 0.8938 - val_loss: 0.2802 - val_acc: 0.9178
# Epoch 42/100
# 1168/1168 [==============================] - 0s 112us/step - loss: 0.2343 - acc: 0.8990 - val_loss: 0.2809 - val_acc: 0.9178
# Epoch 43/100
# 1168/1168 [==============================] - 0s 114us/step - loss: 0.2373 - acc: 0.8878 - val_loss: 0.2809 - val_acc: 0.9178
# Epoch 44/100
# 1168/1168 [==============================] - 0s 103us/step - loss: 0.2368 - acc: 0.8938 - val_loss: 0.2824 - val_acc: 0.9178
# Epoch 45/100
# 1168/1168 [==============================] - 0s 101us/step - loss: 0.2342 - acc: 0.8930 - val_loss: 0.2830 - val_acc: 0.9178
# Epoch 46/100
# 1168/1168 [==============================] - 0s 113us/step - loss: 0.2390 - acc: 0.8947 - val_loss: 0.2829 - val_acc: 0.9178
# Epoch 47/100
# 1168/1168 [==============================] - 0s 110us/step - loss: 0.2294 - acc: 0.8921 - val_loss: 0.2829 - val_acc: 0.9178
# Epoch 48/100
# 1168/1168 [==============================] - 0s 102us/step - loss: 0.2325 - acc: 0.8947 - val_loss: 0.2842 - val_acc: 0.9178
# Epoch 49/100
# 1168/1168 [==============================] - 0s 108us/step - loss: 0.2373 - acc: 0.8896 - val_loss: 0.2844 - val_acc: 0.9178
# Epoch 50/100
# 1168/1168 [==============================] - 0s 123us/step - loss: 0.2334 - acc: 0.8938 - val_loss: 0.2847 - val_acc: 0.9178
# Epoch 51/100
# 1168/1168 [==============================] - 0s 100us/step - loss: 0.2392 - acc: 0.8930 - val_loss: 0.2847 - val_acc: 0.9178
# Epoch 52/100
# 1168/1168 [==============================] - 0s 104us/step - loss: 0.2314 - acc: 0.8870 - val_loss: 0.2858 - val_acc: 0.9178
# Epoch 53/100
# 1168/1168 [==============================] - 0s 110us/step - loss: 0.2312 - acc: 0.8973 - val_loss: 0.2859 - val_acc: 0.9178
# Epoch 54/100
# 1168/1168 [==============================] - 0s 98us/step - loss: 0.2338 - acc: 0.8930 - val_loss: 0.2859 - val_acc: 0.9178
# Epoch 55/100
# 1168/1168 [==============================] - 0s 121us/step - loss: 0.2375 - acc: 0.8955 - val_loss: 0.2865 - val_acc: 0.9178
# Epoch 56/100
# 1168/1168 [==============================] - 0s 116us/step - loss: 0.2353 - acc: 0.8955 - val_loss: 0.2865 - val_acc: 0.9178
# Epoch 57/100
# 1168/1168 [==============================] - 0s 105us/step - loss: 0.2276 - acc: 0.8913 - val_loss: 0.2868 - val_acc: 0.9178
# Epoch 58/100
# 1168/1168 [==============================] - 0s 105us/step - loss: 0.2278 - acc: 0.8947 - val_loss: 0.2876 - val_acc: 0.9178
# Epoch 59/100
# 1168/1168 [==============================] - 0s 106us/step - loss: 0.2307 - acc: 0.8913 - val_loss: 0.2893 - val_acc: 0.9178
# Epoch 60/100
# 1168/1168 [==============================] - 0s 112us/step - loss: 0.2318 - acc: 0.8930 - val_loss: 0.2893 - val_acc: 0.9178
# Epoch 61/100
# 1168/1168 [==============================] - 0s 100us/step - loss: 0.2356 - acc: 0.8947 - val_loss: 0.2887 - val_acc: 0.9178
# Epoch 62/100
# 1168/1168 [==============================] - 0s 104us/step - loss: 0.2265 - acc: 0.8938 - val_loss: 0.2888 - val_acc: 0.9178
# Epoch 63/100
# 1168/1168 [==============================] - 0s 99us/step - loss: 0.2360 - acc: 0.8896 - val_loss: 0.2900 - val_acc: 0.9178
# Epoch 64/100
# 1168/1168 [==============================] - 0s 146us/step - loss: 0.2372 - acc: 0.8896 - val_loss: 0.2896 - val_acc: 0.9178
# Epoch 65/100
# 1168/1168 [==============================] - 0s 109us/step - loss: 0.2398 - acc: 0.8887 - val_loss: 0.2905 - val_acc: 0.9178
# Epoch 66/100
# 1168/1168 [==============================] - 0s 114us/step - loss: 0.2311 - acc: 0.8981 - val_loss: 0.2902 - val_acc: 0.9178
# Epoch 67/100
# 1168/1168 [==============================] - 0s 97us/step - loss: 0.2384 - acc: 0.8938 - val_loss: 0.2902 - val_acc: 0.9178
# Epoch 68/100
# 1168/1168 [==============================] - 0s 117us/step - loss: 0.2332 - acc: 0.8998 - val_loss: 0.2914 - val_acc: 0.9178
# Epoch 69/100
# 1168/1168 [==============================] - 0s 105us/step - loss: 0.2343 - acc: 0.8955 - val_loss: 0.2903 - val_acc: 0.9178
# Epoch 70/100
# 1168/1168 [==============================] - 0s 110us/step - loss: 0.2317 - acc: 0.8990 - val_loss: 0.2909 - val_acc: 0.9178
# Epoch 71/100
# 1168/1168 [==============================] - 0s 107us/step - loss: 0.2341 - acc: 0.8955 - val_loss: 0.2921 - val_acc: 0.9178
# Epoch 72/100
# 1168/1168 [==============================] - 0s 111us/step - loss: 0.2369 - acc: 0.8904 - val_loss: 0.2919 - val_acc: 0.9178
# Epoch 73/100
# 1168/1168 [==============================] - 0s 101us/step - loss: 0.2263 - acc: 0.8955 - val_loss: 0.2918 - val_acc: 0.9178
# Epoch 74/100
# 1168/1168 [==============================] - 0s 114us/step - loss: 0.2353 - acc: 0.8964 - val_loss: 0.2926 - val_acc: 0.9178
# Epoch 75/100
# 1168/1168 [==============================] - 0s 100us/step - loss: 0.2361 - acc: 0.8955 - val_loss: 0.2931 - val_acc: 0.9178
# Epoch 76/100
# 1168/1168 [==============================] - 0s 106us/step - loss: 0.2352 - acc: 0.8955 - val_loss: 0.2931 - val_acc: 0.9178
# Epoch 77/100
# 1168/1168 [==============================] - 0s 99us/step - loss: 0.2305 - acc: 0.8981 - val_loss: 0.2924 - val_acc: 0.9178
# Epoch 78/100
# 1168/1168 [==============================] - 0s 112us/step - loss: 0.2265 - acc: 0.9024 - val_loss: 0.2941 - val_acc: 0.9178
# Epoch 79/100
# 1168/1168 [==============================] - 0s 112us/step - loss: 0.2323 - acc: 0.8990 - val_loss: 0.2936 - val_acc: 0.9178
# Epoch 80/100
# 1168/1168 [==============================] - 0s 132us/step - loss: 0.2345 - acc: 0.8964 - val_loss: 0.2927 - val_acc: 0.9178
# Epoch 81/100
# 1168/1168 [==============================] - 0s 118us/step - loss: 0.2283 - acc: 0.8930 - val_loss: 0.2939 - val_acc: 0.9178
# Epoch 82/100
# 1168/1168 [==============================] - 0s 116us/step - loss: 0.2273 - acc: 0.8973 - val_loss: 0.2946 - val_acc: 0.9178
# Epoch 83/100
# 1168/1168 [==============================] - 0s 113us/step - loss: 0.2315 - acc: 0.8947 - val_loss: 0.2949 - val_acc: 0.9178
# Epoch 84/100
# 1168/1168 [==============================] - 0s 111us/step - loss: 0.2383 - acc: 0.9007 - val_loss: 0.2956 - val_acc: 0.9178
# Epoch 85/100
# 1168/1168 [==============================] - 0s 96us/step - loss: 0.2292 - acc: 0.8981 - val_loss: 0.2963 - val_acc: 0.9178
# Epoch 86/100
# 1168/1168 [==============================] - 0s 113us/step - loss: 0.2302 - acc: 0.8998 - val_loss: 0.2965 - val_acc: 0.9178
# Epoch 87/100
# 1168/1168 [==============================] - 0s 104us/step - loss: 0.2300 - acc: 0.8930 - val_loss: 0.2980 - val_acc: 0.9178
# Epoch 88/100
# 1168/1168 [==============================] - 0s 132us/step - loss: 0.2301 - acc: 0.8904 - val_loss: 0.2965 - val_acc: 0.9178
# Epoch 89/100
# 1168/1168 [==============================] - 0s 102us/step - loss: 0.2255 - acc: 0.8964 - val_loss: 0.2961 - val_acc: 0.9178
# Epoch 90/100
# 1168/1168 [==============================] - 0s 109us/step - loss: 0.2290 - acc: 0.8973 - val_loss: 0.2960 - val_acc: 0.9178
# Epoch 91/100
# 1168/1168 [==============================] - 0s 104us/step - loss: 0.2302 - acc: 0.8981 - val_loss: 0.2971 - val_acc: 0.9178
# Epoch 92/100
# 1168/1168 [==============================] - 0s 102us/step - loss: 0.2298 - acc: 0.8947 - val_loss: 0.2971 - val_acc: 0.9178
# Epoch 93/100
# 1168/1168 [==============================] - 0s 107us/step - loss: 0.2250 - acc: 0.8973 - val_loss: 0.2976 - val_acc: 0.9178
# Epoch 94/100
# 1168/1168 [==============================] - 0s 112us/step - loss: 0.2260 - acc: 0.8998 - val_loss: 0.2979 - val_acc: 0.9178
# Epoch 95/100
# 1168/1168 [==============================] - 0s 103us/step - loss: 0.2289 - acc: 0.8990 - val_loss: 0.2985 - val_acc: 0.9178
# Epoch 96/100
# 1168/1168 [==============================] - 0s 103us/step - loss: 0.2255 - acc: 0.8964 - val_loss: 0.2984 - val_acc: 0.9178
# Epoch 97/100
# 1168/1168 [==============================] - 0s 106us/step - loss: 0.2361 - acc: 0.8964 - val_loss: 0.2987 - val_acc: 0.9178
# Epoch 98/100
# 1168/1168 [==============================] - 0s 115us/step - loss: 0.2333 - acc: 0.8998 - val_loss: 0.2982 - val_acc: 0.9178
# Epoch 99/100
# 1168/1168 [==============================] - 0s 111us/step - loss: 0.2281 - acc: 0.8955 - val_loss: 0.2994 - val_acc: 0.9178
# Epoch 100/100
# 1168/1168 [==============================] - 0s 115us/step - loss: 0.2297 - acc: 0.8938 - val_loss: 0.2981 - val_acc: 0.9178

# %%
# Plot Precisión

plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('Precisión')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['Train', 'Test'], loc='lower right')
plt.show()

# Plot Pérdida

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Pérdida')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper right')
plt.show()
