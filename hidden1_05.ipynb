# %%
###########################

# Problema de clasificación:
# y: arriba o abajo de la mediana del precio de la vivienda

# %%
# Librerías
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv('dataset.csv')

# %%
dataset.head(20)
# Out:
#     LotArea  OverallQual  OverallCond  TotalBsmtSF  FullBath  HalfBath  \
# 0      8450            7            5          856         2         1
# 1      9600            6            8         1262         2         0
# 2     11250            7            5          920         2         1
# 3      9550            7            5          756         1         0
# 4     14260            8            5         1145         2         1
# 5     14115            5            5          796         1         1
# 6     10084            8            5         1686         2         0
# 7     10382            7            6         1107         2         1
# 8      6120            7            5          952         2         0
# 9      7420            5            6          991         1         0
# 10    11200            5            5         1040         1         0
# 11    11924            9            5         1175         3         0
# 12    12968            5            6          912         1         0
# 13    10652            7            5         1494         2         0
# 14    10920            6            5         1253         1         1
# 15     6120            7            8          832         1         0
# 16    11241            6            7         1004         1         0
# 17    10791            4            5            0         2         0
# 18    13695            5            5         1114         1         1
# 19     7560            5            6         1029         1         0
#
#     BedroomAbvGr  TotRmsAbvGrd  Fireplaces  GarageArea  AboveMedianPrice
# 0              3             8           0         548                 1
# 1              3             6           1         460                 1
# 2              3             6           1         608                 1
# 3              3             7           1         642                 0
# 4              4             9           1         836                 1
# 5              1             5           0         480                 0
# 6              3             7           1         636                 1
# 7              3             7           2         484                 1
# 8              2             8           2         468                 0
# 9              2             5           2         205                 0
# 10             3             5           0         384                 0
# 11             4            11           2         736                 1
# 12             2             4           0         352                 0
# 13             3             7           1         840                 1
# 14             2             5           1         352                 0
# 15             2             5           0         576                 0
# 16             2             5           1         480                 0
# 17             2             6           0         516                 0
# 18             3             6           0         576                 0
# 19             3             6           0         294                 0

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   LotArea           1460 non-null   int64
#  1   OverallQual       1460 non-null   int64
#  2   OverallCond       1460 non-null   int64
#  3   TotalBsmtSF       1460 non-null   int64
#  4   FullBath          1460 non-null   int64
#  5   HalfBath          1460 non-null   int64
#  6   BedroomAbvGr      1460 non-null   int64
#  7   TotRmsAbvGrd      1460 non-null   int64
#  8   Fireplaces        1460 non-null   int64
#  9   GarageArea        1460 non-null   int64
#  10  AboveMedianPrice  1460 non-null   int64
# dtypes: int64(11)
# memory usage: 125.6 KB

# %%
# Seleccionar variables independientes y variables dependientes
X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, -1].values

# %%
X[:10]
# Out:
# array([[ 8450,     7,     5,   856,     2,     1,     3,     8,     0,
#           548],
#        [ 9600,     6,     8,  1262,     2,     0,     3,     6,     1,
#           460],
#        [11250,     7,     5,   920,     2,     1,     3,     6,     1,
#           608],
#        [ 9550,     7,     5,   756,     1,     0,     3,     7,     1,
#           642],
#        [14260,     8,     5,  1145,     2,     1,     4,     9,     1,
#           836],
#        [14115,     5,     5,   796,     1,     1,     1,     5,     0,
#           480],
#        [10084,     8,     5,  1686,     2,     0,     3,     7,     1,
#           636],
#        [10382,     7,     6,  1107,     2,     1,     3,     7,     2,
#           484],
#        [ 6120,     7,     5,   952,     2,     0,     2,     8,     2,
#           468],
#        [ 7420,     5,     6,   991,     1,     0,     2,     5,     2,
#           205]])

# %%
# como no hay variables categóricas no hace falta transformas ningún dato a variable ficticia.

# %%
# Dividir el dataset en train y test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 0)

# %%
# Escalamos las características, aunque no hay mucha diferencia entre los números pero es una buena práctica
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
import keras
# Out:
# Using TensorFlow backend.

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout

# %%
modelRedNeuronalClasificacion = Sequential()

# %%
# Creamos la capa de entrada y la primer capa hidden en un mismo paso.

# Entrada de la red: 10 características.
input_size = 10

# Tamaño de la capa hidden.
# para el tamaño no hay una regla, se suele tomar el promedio entre la entrada (10) y la salida (1)
hidden_layer_size = 10

# init='uniform' pesos iniciales aleatorios uniformes.
modelRedNeuronalClasificacion.add(Dense(input_dim=input_size, units=hidden_layer_size,kernel_initializer='uniform', activation='relu'))

# %%
# Capa de salida

# Salida de la red: 1 salida, activación sigmoid.
# Activacion sigmoidal ya que la variable dependiente y es una sola categoria, 1 o 0.
output_size = 1
modelRedNeuronalClasificacion.add(Dense(units=output_size,kernel_initializer='uniform', activation='sigmoid'))

# %%
# Compilar la red neuronal
# binary_crossentropy para sigmoid, categorical_crossentropy para softmax (binary_crossentropy en este caso)
# optimizador = adam. Puede ser rmsprop u otros algoritmos.
modelRedNeuronalClasificacion.compile(optimizer='adam', loss='binary_crossentropy', metrics=['acc'])

# %%
# Entrenamiento de la red.
# Tamaño del Batch: observaciones a incluir en el cálculo de la pérdida antes de actualizar los pesos. No hay una regla.
# Epochs: Pasadas completas por todo el dataset.

batch_size = 10
max_epochs = 50

history = modelRedNeuronalClasificacion.fit(X_train, y_train,
            batch_size=batch_size,
            epochs=max_epochs,
            validation_data=(X_test, y_test))
# Out:
# Train on 1022 samples, validate on 438 samples
# Epoch 1/50
# 1022/1022 [==============================] - 0s 476us/step - loss: 0.6543 - acc: 0.8386 - val_loss: 0.5689 - val_acc: 0.8813
# Epoch 2/50
# 1022/1022 [==============================] - 0s 339us/step - loss: 0.4641 - acc: 0.8777 - val_loss: 0.3719 - val_acc: 0.8927
# Epoch 3/50
# 1022/1022 [==============================] - 0s 316us/step - loss: 0.3286 - acc: 0.8836 - val_loss: 0.2991 - val_acc: 0.9064
# Epoch 4/50
# 1022/1022 [==============================] - 0s 305us/step - loss: 0.2777 - acc: 0.8865 - val_loss: 0.2744 - val_acc: 0.9132
# Epoch 5/50
# 1022/1022 [==============================] - 0s 305us/step - loss: 0.2576 - acc: 0.8875 - val_loss: 0.2645 - val_acc: 0.9155
# Epoch 6/50
# 1022/1022 [==============================] - 0s 324us/step - loss: 0.2477 - acc: 0.8943 - val_loss: 0.2601 - val_acc: 0.9132
# Epoch 7/50
# 1022/1022 [==============================] - 0s 330us/step - loss: 0.2417 - acc: 0.8894 - val_loss: 0.2584 - val_acc: 0.9155
# Epoch 8/50
# 1022/1022 [==============================] - 0s 352us/step - loss: 0.2376 - acc: 0.8924 - val_loss: 0.2580 - val_acc: 0.9155
# Epoch 9/50
# 1022/1022 [==============================] - 0s 335us/step - loss: 0.2348 - acc: 0.8933 - val_loss: 0.2566 - val_acc: 0.9178
# Epoch 10/50
# 1022/1022 [==============================] - 0s 300us/step - loss: 0.2325 - acc: 0.8904 - val_loss: 0.2568 - val_acc: 0.9132
# Epoch 11/50
# 1022/1022 [==============================] - 0s 309us/step - loss: 0.2303 - acc: 0.8973 - val_loss: 0.2569 - val_acc: 0.9110
# Epoch 12/50
# 1022/1022 [==============================] - 0s 327us/step - loss: 0.2288 - acc: 0.8943 - val_loss: 0.2574 - val_acc: 0.9087
# Epoch 13/50
# 1022/1022 [==============================] - 0s 354us/step - loss: 0.2270 - acc: 0.8953 - val_loss: 0.2573 - val_acc: 0.9087
# Epoch 14/50
# 1022/1022 [==============================] - 0s 319us/step - loss: 0.2260 - acc: 0.8943 - val_loss: 0.2574 - val_acc: 0.9087
# Epoch 15/50
# 1022/1022 [==============================] - 0s 330us/step - loss: 0.2250 - acc: 0.9002 - val_loss: 0.2585 - val_acc: 0.9110
# Epoch 16/50
# 1022/1022 [==============================] - 0s 301us/step - loss: 0.2241 - acc: 0.9012 - val_loss: 0.2581 - val_acc: 0.9087
# Epoch 17/50
# 1022/1022 [==============================] - 0s 327us/step - loss: 0.2231 - acc: 0.9012 - val_loss: 0.2584 - val_acc: 0.9132
# Epoch 18/50
# 1022/1022 [==============================] - 0s 330us/step - loss: 0.2223 - acc: 0.9002 - val_loss: 0.2584 - val_acc: 0.9132
# Epoch 19/50
# 1022/1022 [==============================] - 0s 313us/step - loss: 0.2220 - acc: 0.9012 - val_loss: 0.2593 - val_acc: 0.9110
# Epoch 20/50
# 1022/1022 [==============================] - 0s 322us/step - loss: 0.2209 - acc: 0.8992 - val_loss: 0.2593 - val_acc: 0.9132
# Epoch 21/50
# 1022/1022 [==============================] - 0s 317us/step - loss: 0.2202 - acc: 0.8992 - val_loss: 0.2596 - val_acc: 0.9110
# Epoch 22/50
# 1022/1022 [==============================] - 0s 311us/step - loss: 0.2195 - acc: 0.9022 - val_loss: 0.2602 - val_acc: 0.9132
# Epoch 23/50
# 1022/1022 [==============================] - 0s 329us/step - loss: 0.2188 - acc: 0.9002 - val_loss: 0.2594 - val_acc: 0.9132
# Epoch 24/50
# 1022/1022 [==============================] - 0s 312us/step - loss: 0.2183 - acc: 0.8982 - val_loss: 0.2582 - val_acc: 0.9132
# Epoch 25/50
# 1022/1022 [==============================] - 0s 305us/step - loss: 0.2179 - acc: 0.9002 - val_loss: 0.2600 - val_acc: 0.9132
# Epoch 26/50
# 1022/1022 [==============================] - 0s 299us/step - loss: 0.2174 - acc: 0.8973 - val_loss: 0.2590 - val_acc: 0.9155
# Epoch 27/50
# 1022/1022 [==============================] - 0s 333us/step - loss: 0.2169 - acc: 0.8973 - val_loss: 0.2597 - val_acc: 0.9132
# Epoch 28/50
# 1022/1022 [==============================] - 0s 324us/step - loss: 0.2166 - acc: 0.8973 - val_loss: 0.2598 - val_acc: 0.9155
# Epoch 29/50
# 1022/1022 [==============================] - 0s 323us/step - loss: 0.2159 - acc: 0.9012 - val_loss: 0.2611 - val_acc: 0.9132
# Epoch 30/50
# 1022/1022 [==============================] - 0s 338us/step - loss: 0.2155 - acc: 0.8992 - val_loss: 0.2610 - val_acc: 0.9155
# Epoch 31/50
# 1022/1022 [==============================] - 0s 313us/step - loss: 0.2151 - acc: 0.9002 - val_loss: 0.2607 - val_acc: 0.9155
# Epoch 32/50
# 1022/1022 [==============================] - 0s 321us/step - loss: 0.2151 - acc: 0.8982 - val_loss: 0.2611 - val_acc: 0.9132
# Epoch 33/50
# 1022/1022 [==============================] - 0s 325us/step - loss: 0.2147 - acc: 0.9002 - val_loss: 0.2608 - val_acc: 0.9132
# Epoch 34/50
# 1022/1022 [==============================] - 0s 321us/step - loss: 0.2140 - acc: 0.8982 - val_loss: 0.2616 - val_acc: 0.9155
# Epoch 35/50
# 1022/1022 [==============================] - 0s 323us/step - loss: 0.2138 - acc: 0.9031 - val_loss: 0.2613 - val_acc: 0.9155
# Epoch 36/50
# 1022/1022 [==============================] - 0s 307us/step - loss: 0.2134 - acc: 0.9031 - val_loss: 0.2620 - val_acc: 0.9155
# Epoch 37/50
# 1022/1022 [==============================] - 0s 321us/step - loss: 0.2131 - acc: 0.8982 - val_loss: 0.2619 - val_acc: 0.9155
# Epoch 38/50
# 1022/1022 [==============================] - 0s 310us/step - loss: 0.2129 - acc: 0.9022 - val_loss: 0.2617 - val_acc: 0.9155
# Epoch 39/50
# 1022/1022 [==============================] - 0s 362us/step - loss: 0.2128 - acc: 0.9002 - val_loss: 0.2605 - val_acc: 0.9110
# Epoch 40/50
# 1022/1022 [==============================] - 0s 316us/step - loss: 0.2120 - acc: 0.9002 - val_loss: 0.2615 - val_acc: 0.9155
# Epoch 41/50
# 1022/1022 [==============================] - 0s 316us/step - loss: 0.2120 - acc: 0.9002 - val_loss: 0.2623 - val_acc: 0.9155
# Epoch 42/50
# 1022/1022 [==============================] - 0s 317us/step - loss: 0.2114 - acc: 0.9022 - val_loss: 0.2620 - val_acc: 0.9155
# Epoch 43/50
# 1022/1022 [==============================] - 0s 324us/step - loss: 0.2110 - acc: 0.9041 - val_loss: 0.2619 - val_acc: 0.9110
# Epoch 44/50
# 1022/1022 [==============================] - 0s 318us/step - loss: 0.2109 - acc: 0.9022 - val_loss: 0.2624 - val_acc: 0.9132
# Epoch 45/50
# 1022/1022 [==============================] - 0s 316us/step - loss: 0.2107 - acc: 0.9031 - val_loss: 0.2628 - val_acc: 0.9132
# Epoch 46/50
# 1022/1022 [==============================] - 0s 370us/step - loss: 0.2106 - acc: 0.9022 - val_loss: 0.2640 - val_acc: 0.9110
# Epoch 47/50
# 1022/1022 [==============================] - 0s 319us/step - loss: 0.2100 - acc: 0.9031 - val_loss: 0.2642 - val_acc: 0.9087
# Epoch 48/50
# 1022/1022 [==============================] - 0s 324us/step - loss: 0.2100 - acc: 0.9012 - val_loss: 0.2639 - val_acc: 0.9110
# Epoch 49/50
# 1022/1022 [==============================] - 0s 315us/step - loss: 0.2095 - acc: 0.9031 - val_loss: 0.2650 - val_acc: 0.9110
# Epoch 50/50
# 1022/1022 [==============================] - 0s 289us/step - loss: 0.2094 - acc: 0.9022 - val_loss: 0.2647 - val_acc: 0.9087

# %%
# Plot Precisión

plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('Precisión')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['Train', 'Test'], loc='lower right')
plt.show()

# Plot Pérdida

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Pérdida')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper right')
plt.show()
