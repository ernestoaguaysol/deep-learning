# %%
###########################

# Problema de clasificación:
# y: arriba o abajo de la mediana del precio de la vivienda

# %%
# Librerías
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv('dataset.csv')

# %%
dataset.head(20)
# Out:
#     LotArea  OverallQual  OverallCond  TotalBsmtSF  FullBath  HalfBath  \
# 0      8450            7            5          856         2         1
# 1      9600            6            8         1262         2         0
# 2     11250            7            5          920         2         1
# 3      9550            7            5          756         1         0
# 4     14260            8            5         1145         2         1
# 5     14115            5            5          796         1         1
# 6     10084            8            5         1686         2         0
# 7     10382            7            6         1107         2         1
# 8      6120            7            5          952         2         0
# 9      7420            5            6          991         1         0
# 10    11200            5            5         1040         1         0
# 11    11924            9            5         1175         3         0
# 12    12968            5            6          912         1         0
# 13    10652            7            5         1494         2         0
# 14    10920            6            5         1253         1         1
# 15     6120            7            8          832         1         0
# 16    11241            6            7         1004         1         0
# 17    10791            4            5            0         2         0
# 18    13695            5            5         1114         1         1
# 19     7560            5            6         1029         1         0
#
#     BedroomAbvGr  TotRmsAbvGrd  Fireplaces  GarageArea  AboveMedianPrice
# 0              3             8           0         548                 1
# 1              3             6           1         460                 1
# 2              3             6           1         608                 1
# 3              3             7           1         642                 0
# 4              4             9           1         836                 1
# 5              1             5           0         480                 0
# 6              3             7           1         636                 1
# 7              3             7           2         484                 1
# 8              2             8           2         468                 0
# 9              2             5           2         205                 0
# 10             3             5           0         384                 0
# 11             4            11           2         736                 1
# 12             2             4           0         352                 0
# 13             3             7           1         840                 1
# 14             2             5           1         352                 0
# 15             2             5           0         576                 0
# 16             2             5           1         480                 0
# 17             2             6           0         516                 0
# 18             3             6           0         576                 0
# 19             3             6           0         294                 0

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   LotArea           1460 non-null   int64
#  1   OverallQual       1460 non-null   int64
#  2   OverallCond       1460 non-null   int64
#  3   TotalBsmtSF       1460 non-null   int64
#  4   FullBath          1460 non-null   int64
#  5   HalfBath          1460 non-null   int64
#  6   BedroomAbvGr      1460 non-null   int64
#  7   TotRmsAbvGrd      1460 non-null   int64
#  8   Fireplaces        1460 non-null   int64
#  9   GarageArea        1460 non-null   int64
#  10  AboveMedianPrice  1460 non-null   int64
# dtypes: int64(11)
# memory usage: 125.6 KB

# %%
# Seleccionar variables independientes y variables dependientes
X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, -1].values

# %%
X[:10]
# Out:
# array([[ 8450,     7,     5,   856,     2,     1,     3,     8,     0,
#           548],
#        [ 9600,     6,     8,  1262,     2,     0,     3,     6,     1,
#           460],
#        [11250,     7,     5,   920,     2,     1,     3,     6,     1,
#           608],
#        [ 9550,     7,     5,   756,     1,     0,     3,     7,     1,
#           642],
#        [14260,     8,     5,  1145,     2,     1,     4,     9,     1,
#           836],
#        [14115,     5,     5,   796,     1,     1,     1,     5,     0,
#           480],
#        [10084,     8,     5,  1686,     2,     0,     3,     7,     1,
#           636],
#        [10382,     7,     6,  1107,     2,     1,     3,     7,     2,
#           484],
#        [ 6120,     7,     5,   952,     2,     0,     2,     8,     2,
#           468],
#        [ 7420,     5,     6,   991,     1,     0,     2,     5,     2,
#           205]])

# %%
# como no hay variables categóricas no hace falta transformas ningún dato a variable ficticia.

# %%
# Dividir el dataset en train y test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
# Escalamos las características, aunque no hay mucha diferencia entre los números pero es una buena práctica
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
import keras
# Out:
# Using TensorFlow backend.

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout

# %%
modelRedNeuronalClasificacion = Sequential()

# %%
# Creamos la capa de entrada y la primer capa hidden en un mismo paso.

# Entrada de la red: 10 características.
input_size = 10

# Tamaño de la capa hidden.
# para el tamaño no hay una regla, se suele tomar el promedio entre la entrada (10) y la salida (1)
hidden_layer_size = 5

# init='uniform' pesos iniciales aleatorios uniformes.
modelRedNeuronalClasificacion.add(Dense(input_dim=input_size, units=hidden_layer_size,kernel_initializer='uniform', activation='relu'))

# %%
# Capa de salida

# Salida de la red: 1 salida, activación sigmoid.
# Activacion sigmoidal ya que la variable dependiente y es una sola categoria, 1 o 0.
output_size = 1
modelRedNeuronalClasificacion.add(Dense(units=output_size,kernel_initializer='uniform', activation='sigmoid'))

# %%
# Compilar la red neuronal
# binary_crossentropy para sigmoid, categorical_crossentropy para softmax (binary_crossentropy en este caso)
# optimizador = adam. Puede ser rmsprop u otros algoritmos.
modelRedNeuronalClasificacion.compile(optimizer='adam', loss='binary_crossentropy', metrics=['acc'])

# %%
# Entrenamiento de la red.
# Tamaño del Batch: observaciones a incluir en el cálculo de la pérdida antes de actualizar los pesos. No hay una regla.
# Epochs: Pasadas completas por todo el dataset.

batch_size = 25
max_epochs = 100

history = modelRedNeuronalClasificacion.fit(X_train, y_train,
            batch_size=batch_size,
            epochs=max_epochs,
            validation_data=(X_test, y_test))
# Out:
# Train on 1168 samples, validate on 292 samples
# Epoch 1/100
# 1168/1168 [==============================] - 0s 357us/step - loss: 0.6887 - acc: 0.7765 - val_loss: 0.6784 - val_acc: 0.9075
# Epoch 2/100
# 1168/1168 [==============================] - 0s 121us/step - loss: 0.6578 - acc: 0.8690 - val_loss: 0.6212 - val_acc: 0.8973
# Epoch 3/100
# 1168/1168 [==============================] - 0s 114us/step - loss: 0.5900 - acc: 0.8690 - val_loss: 0.5370 - val_acc: 0.8938
# Epoch 4/100
# 1168/1168 [==============================] - 0s 113us/step - loss: 0.5120 - acc: 0.8733 - val_loss: 0.4605 - val_acc: 0.9110
# Epoch 5/100
# 1168/1168 [==============================] - 0s 134us/step - loss: 0.4465 - acc: 0.8767 - val_loss: 0.4023 - val_acc: 0.9144
# Epoch 6/100
# 1168/1168 [==============================] - 0s 123us/step - loss: 0.3969 - acc: 0.8793 - val_loss: 0.3601 - val_acc: 0.9178
# Epoch 7/100
# 1168/1168 [==============================] - 0s 127us/step - loss: 0.3595 - acc: 0.8844 - val_loss: 0.3313 - val_acc: 0.9178
# Epoch 8/100
# 1168/1168 [==============================] - 0s 134us/step - loss: 0.3321 - acc: 0.8870 - val_loss: 0.3101 - val_acc: 0.9178
# Epoch 9/100
# 1168/1168 [==============================] - 0s 134us/step - loss: 0.3117 - acc: 0.8896 - val_loss: 0.2950 - val_acc: 0.9212
# Epoch 10/100
# 1168/1168 [==============================] - 0s 101us/step - loss: 0.2963 - acc: 0.8904 - val_loss: 0.2844 - val_acc: 0.9178
# Epoch 11/100
# 1168/1168 [==============================] - 0s 103us/step - loss: 0.2844 - acc: 0.8904 - val_loss: 0.2762 - val_acc: 0.9178
# Epoch 12/100
# 1168/1168 [==============================] - 0s 135us/step - loss: 0.2754 - acc: 0.8921 - val_loss: 0.2704 - val_acc: 0.9212
# Epoch 13/100
# 1168/1168 [==============================] - 0s 157us/step - loss: 0.2682 - acc: 0.8921 - val_loss: 0.2670 - val_acc: 0.9212
# Epoch 14/100
# 1168/1168 [==============================] - 0s 132us/step - loss: 0.2623 - acc: 0.8947 - val_loss: 0.2639 - val_acc: 0.9247
# Epoch 15/100
# 1168/1168 [==============================] - 0s 112us/step - loss: 0.2578 - acc: 0.8947 - val_loss: 0.2614 - val_acc: 0.9281
# Epoch 16/100
# 1168/1168 [==============================] - 0s 108us/step - loss: 0.2538 - acc: 0.8921 - val_loss: 0.2599 - val_acc: 0.9281
# Epoch 17/100
# 1168/1168 [==============================] - 0s 137us/step - loss: 0.2508 - acc: 0.8947 - val_loss: 0.2587 - val_acc: 0.9281
# Epoch 18/100
# 1168/1168 [==============================] - 0s 131us/step - loss: 0.2480 - acc: 0.8955 - val_loss: 0.2579 - val_acc: 0.9281
# Epoch 19/100
# 1168/1168 [==============================] - 0s 104us/step - loss: 0.2457 - acc: 0.8955 - val_loss: 0.2575 - val_acc: 0.9212
# Epoch 20/100
# 1168/1168 [==============================] - 0s 120us/step - loss: 0.2436 - acc: 0.8913 - val_loss: 0.2567 - val_acc: 0.9212
# Epoch 21/100
# 1168/1168 [==============================] - 0s 105us/step - loss: 0.2418 - acc: 0.8913 - val_loss: 0.2569 - val_acc: 0.9247
# Epoch 22/100
# 1168/1168 [==============================] - 0s 145us/step - loss: 0.2402 - acc: 0.8896 - val_loss: 0.2572 - val_acc: 0.9247
# Epoch 23/100
# 1168/1168 [==============================] - 0s 123us/step - loss: 0.2387 - acc: 0.8896 - val_loss: 0.2567 - val_acc: 0.9247
# Epoch 24/100
# 1168/1168 [==============================] - 0s 120us/step - loss: 0.2373 - acc: 0.8878 - val_loss: 0.2567 - val_acc: 0.9212
# Epoch 25/100
# 1168/1168 [==============================] - 0s 150us/step - loss: 0.2361 - acc: 0.8887 - val_loss: 0.2568 - val_acc: 0.9212
# Epoch 26/100
# 1168/1168 [==============================] - 0s 142us/step - loss: 0.2352 - acc: 0.8904 - val_loss: 0.2569 - val_acc: 0.9212
# Epoch 27/100
# 1168/1168 [==============================] - 0s 117us/step - loss: 0.2344 - acc: 0.8913 - val_loss: 0.2571 - val_acc: 0.9212
# Epoch 28/100
# 1168/1168 [==============================] - 0s 119us/step - loss: 0.2335 - acc: 0.8921 - val_loss: 0.2573 - val_acc: 0.9212
# Epoch 29/100
# 1168/1168 [==============================] - 0s 115us/step - loss: 0.2328 - acc: 0.8896 - val_loss: 0.2582 - val_acc: 0.9212
# Epoch 30/100
# 1168/1168 [==============================] - 0s 137us/step - loss: 0.2321 - acc: 0.8896 - val_loss: 0.2582 - val_acc: 0.9212
# Epoch 31/100
# 1168/1168 [==============================] - 0s 143us/step - loss: 0.2315 - acc: 0.8930 - val_loss: 0.2584 - val_acc: 0.9212
# Epoch 32/100
# 1168/1168 [==============================] - 0s 178us/step - loss: 0.2310 - acc: 0.8921 - val_loss: 0.2588 - val_acc: 0.9212
# Epoch 33/100
# 1168/1168 [==============================] - 0s 121us/step - loss: 0.2303 - acc: 0.8913 - val_loss: 0.2585 - val_acc: 0.9212
# Epoch 34/100
# 1168/1168 [==============================] - 0s 151us/step - loss: 0.2299 - acc: 0.8921 - val_loss: 0.2589 - val_acc: 0.9212
# Epoch 35/100
# 1168/1168 [==============================] - 0s 138us/step - loss: 0.2294 - acc: 0.8904 - val_loss: 0.2591 - val_acc: 0.9212
# Epoch 36/100
# 1168/1168 [==============================] - 0s 117us/step - loss: 0.2291 - acc: 0.8921 - val_loss: 0.2601 - val_acc: 0.9212
# Epoch 37/100
# 1168/1168 [==============================] - 0s 125us/step - loss: 0.2287 - acc: 0.8921 - val_loss: 0.2601 - val_acc: 0.9212
# Epoch 38/100
# 1168/1168 [==============================] - 0s 128us/step - loss: 0.2283 - acc: 0.8913 - val_loss: 0.2597 - val_acc: 0.9212
# Epoch 39/100
# 1168/1168 [==============================] - 0s 143us/step - loss: 0.2278 - acc: 0.8921 - val_loss: 0.2606 - val_acc: 0.9212
# Epoch 40/100
# 1168/1168 [==============================] - 0s 147us/step - loss: 0.2273 - acc: 0.8930 - val_loss: 0.2612 - val_acc: 0.9212
# Epoch 41/100
# 1168/1168 [==============================] - 0s 136us/step - loss: 0.2267 - acc: 0.8930 - val_loss: 0.2612 - val_acc: 0.9212
# Epoch 42/100
# 1168/1168 [==============================] - 0s 143us/step - loss: 0.2263 - acc: 0.8947 - val_loss: 0.2614 - val_acc: 0.9212
# Epoch 43/100
# 1168/1168 [==============================] - 0s 124us/step - loss: 0.2259 - acc: 0.8947 - val_loss: 0.2618 - val_acc: 0.9212
# Epoch 44/100
# 1168/1168 [==============================] - 0s 142us/step - loss: 0.2257 - acc: 0.8938 - val_loss: 0.2622 - val_acc: 0.9212
# Epoch 45/100
# 1168/1168 [==============================] - 0s 147us/step - loss: 0.2253 - acc: 0.8964 - val_loss: 0.2618 - val_acc: 0.9212
# Epoch 46/100
# 1168/1168 [==============================] - 0s 130us/step - loss: 0.2251 - acc: 0.8955 - val_loss: 0.2620 - val_acc: 0.9212
# Epoch 47/100
# 1168/1168 [==============================] - 0s 129us/step - loss: 0.2247 - acc: 0.8947 - val_loss: 0.2625 - val_acc: 0.9212
# Epoch 48/100
# 1168/1168 [==============================] - 0s 121us/step - loss: 0.2242 - acc: 0.8964 - val_loss: 0.2629 - val_acc: 0.9212
# Epoch 49/100
# 1168/1168 [==============================] - 0s 151us/step - loss: 0.2240 - acc: 0.8964 - val_loss: 0.2626 - val_acc: 0.9212
# Epoch 50/100
# 1168/1168 [==============================] - 0s 157us/step - loss: 0.2235 - acc: 0.8947 - val_loss: 0.2633 - val_acc: 0.9212
# Epoch 51/100
# 1168/1168 [==============================] - 0s 144us/step - loss: 0.2233 - acc: 0.8955 - val_loss: 0.2629 - val_acc: 0.9212
# Epoch 52/100
# 1168/1168 [==============================] - 0s 134us/step - loss: 0.2230 - acc: 0.8955 - val_loss: 0.2635 - val_acc: 0.9212
# Epoch 53/100
# 1168/1168 [==============================] - 0s 141us/step - loss: 0.2228 - acc: 0.8947 - val_loss: 0.2630 - val_acc: 0.9212
# Epoch 54/100
# 1168/1168 [==============================] - 0s 133us/step - loss: 0.2223 - acc: 0.8955 - val_loss: 0.2633 - val_acc: 0.9212
# Epoch 55/100
# 1168/1168 [==============================] - 0s 115us/step - loss: 0.2223 - acc: 0.8947 - val_loss: 0.2632 - val_acc: 0.9212
# Epoch 56/100
# 1168/1168 [==============================] - 0s 119us/step - loss: 0.2220 - acc: 0.8964 - val_loss: 0.2632 - val_acc: 0.9212
# Epoch 57/100
# 1168/1168 [==============================] - 0s 116us/step - loss: 0.2218 - acc: 0.8964 - val_loss: 0.2643 - val_acc: 0.9212
# Epoch 58/100
# 1168/1168 [==============================] - 0s 123us/step - loss: 0.2214 - acc: 0.8964 - val_loss: 0.2640 - val_acc: 0.9212
# Epoch 59/100
# 1168/1168 [==============================] - 0s 128us/step - loss: 0.2212 - acc: 0.8964 - val_loss: 0.2639 - val_acc: 0.9247
# Epoch 60/100
# 1168/1168 [==============================] - 0s 128us/step - loss: 0.2210 - acc: 0.8964 - val_loss: 0.2643 - val_acc: 0.9212
# Epoch 61/100
# 1168/1168 [==============================] - 0s 141us/step - loss: 0.2208 - acc: 0.8964 - val_loss: 0.2645 - val_acc: 0.9247
# Epoch 62/100
# 1168/1168 [==============================] - 0s 138us/step - loss: 0.2208 - acc: 0.8964 - val_loss: 0.2645 - val_acc: 0.9212
# Epoch 63/100
# 1168/1168 [==============================] - 0s 126us/step - loss: 0.2206 - acc: 0.8964 - val_loss: 0.2643 - val_acc: 0.9247
# Epoch 64/100
# 1168/1168 [==============================] - 0s 114us/step - loss: 0.2204 - acc: 0.8964 - val_loss: 0.2647 - val_acc: 0.9247
# Epoch 65/100
# 1168/1168 [==============================] - 0s 132us/step - loss: 0.2203 - acc: 0.8964 - val_loss: 0.2649 - val_acc: 0.9247
# Epoch 66/100
# 1168/1168 [==============================] - 0s 140us/step - loss: 0.2201 - acc: 0.8973 - val_loss: 0.2652 - val_acc: 0.9247
# Epoch 67/100
# 1168/1168 [==============================] - 0s 147us/step - loss: 0.2197 - acc: 0.8973 - val_loss: 0.2651 - val_acc: 0.9247
# Epoch 68/100
# 1168/1168 [==============================] - 0s 144us/step - loss: 0.2195 - acc: 0.8964 - val_loss: 0.2655 - val_acc: 0.9247
# Epoch 69/100
# 1168/1168 [==============================] - 0s 143us/step - loss: 0.2194 - acc: 0.8981 - val_loss: 0.2652 - val_acc: 0.9247
# Epoch 70/100
# 1168/1168 [==============================] - 0s 153us/step - loss: 0.2192 - acc: 0.8981 - val_loss: 0.2656 - val_acc: 0.9247
# Epoch 71/100
# 1168/1168 [==============================] - 0s 167us/step - loss: 0.2190 - acc: 0.8981 - val_loss: 0.2660 - val_acc: 0.9247
# Epoch 72/100
# 1168/1168 [==============================] - 0s 134us/step - loss: 0.2191 - acc: 0.8973 - val_loss: 0.2655 - val_acc: 0.9247
# Epoch 73/100
# 1168/1168 [==============================] - 0s 124us/step - loss: 0.2189 - acc: 0.8981 - val_loss: 0.2659 - val_acc: 0.9247
# Epoch 74/100
# 1168/1168 [==============================] - 0s 132us/step - loss: 0.2187 - acc: 0.8981 - val_loss: 0.2667 - val_acc: 0.9247
# Epoch 75/100
# 1168/1168 [==============================] - 0s 133us/step - loss: 0.2186 - acc: 0.8964 - val_loss: 0.2666 - val_acc: 0.9247
# Epoch 76/100
# 1168/1168 [==============================] - 0s 127us/step - loss: 0.2186 - acc: 0.8973 - val_loss: 0.2666 - val_acc: 0.9247
# Epoch 77/100
# 1168/1168 [==============================] - 0s 111us/step - loss: 0.2182 - acc: 0.8964 - val_loss: 0.2667 - val_acc: 0.9247
# Epoch 78/100
# 1168/1168 [==============================] - 0s 117us/step - loss: 0.2181 - acc: 0.8981 - val_loss: 0.2673 - val_acc: 0.9247
# Epoch 79/100
# 1168/1168 [==============================] - 0s 114us/step - loss: 0.2180 - acc: 0.8964 - val_loss: 0.2667 - val_acc: 0.9247
# Epoch 80/100
# 1168/1168 [==============================] - 0s 158us/step - loss: 0.2177 - acc: 0.8964 - val_loss: 0.2672 - val_acc: 0.9247
# Epoch 81/100
# 1168/1168 [==============================] - 0s 136us/step - loss: 0.2177 - acc: 0.8973 - val_loss: 0.2671 - val_acc: 0.9247
# Epoch 82/100
# 1168/1168 [==============================] - 0s 127us/step - loss: 0.2176 - acc: 0.8955 - val_loss: 0.2669 - val_acc: 0.9247
# Epoch 83/100
# 1168/1168 [==============================] - 0s 147us/step - loss: 0.2173 - acc: 0.8964 - val_loss: 0.2673 - val_acc: 0.9247
# Epoch 84/100
# 1168/1168 [==============================] - 0s 142us/step - loss: 0.2173 - acc: 0.8990 - val_loss: 0.2671 - val_acc: 0.9281
# Epoch 85/100
# 1168/1168 [==============================] - 0s 134us/step - loss: 0.2171 - acc: 0.8973 - val_loss: 0.2666 - val_acc: 0.9281
# Epoch 86/100
# 1168/1168 [==============================] - 0s 152us/step - loss: 0.2170 - acc: 0.8964 - val_loss: 0.2670 - val_acc: 0.9281
# Epoch 87/100
# 1168/1168 [==============================] - 0s 140us/step - loss: 0.2168 - acc: 0.8964 - val_loss: 0.2671 - val_acc: 0.9281
# Epoch 88/100
# 1168/1168 [==============================] - 0s 139us/step - loss: 0.2169 - acc: 0.8981 - val_loss: 0.2674 - val_acc: 0.9281
# Epoch 89/100
# 1168/1168 [==============================] - 0s 143us/step - loss: 0.2166 - acc: 0.8973 - val_loss: 0.2670 - val_acc: 0.9281
# Epoch 90/100
# 1168/1168 [==============================] - 0s 135us/step - loss: 0.2166 - acc: 0.8990 - val_loss: 0.2673 - val_acc: 0.9281
# Epoch 91/100
# 1168/1168 [==============================] - 0s 161us/step - loss: 0.2163 - acc: 0.8990 - val_loss: 0.2669 - val_acc: 0.9281
# Epoch 92/100
# 1168/1168 [==============================] - 0s 135us/step - loss: 0.2162 - acc: 0.8990 - val_loss: 0.2670 - val_acc: 0.9281
# Epoch 93/100
# 1168/1168 [==============================] - 0s 152us/step - loss: 0.2161 - acc: 0.8964 - val_loss: 0.2669 - val_acc: 0.9281
# Epoch 94/100
# 1168/1168 [==============================] - 0s 131us/step - loss: 0.2160 - acc: 0.8981 - val_loss: 0.2668 - val_acc: 0.9281
# Epoch 95/100
# 1168/1168 [==============================] - 0s 115us/step - loss: 0.2160 - acc: 0.8973 - val_loss: 0.2673 - val_acc: 0.9281
# Epoch 96/100
# 1168/1168 [==============================] - 0s 119us/step - loss: 0.2158 - acc: 0.8981 - val_loss: 0.2673 - val_acc: 0.9247
# Epoch 97/100
# 1168/1168 [==============================] - 0s 113us/step - loss: 0.2157 - acc: 0.8998 - val_loss: 0.2671 - val_acc: 0.9247
# Epoch 98/100
# 1168/1168 [==============================] - 0s 117us/step - loss: 0.2156 - acc: 0.8981 - val_loss: 0.2672 - val_acc: 0.9247
# Epoch 99/100
# 1168/1168 [==============================] - 0s 115us/step - loss: 0.2155 - acc: 0.8981 - val_loss: 0.2677 - val_acc: 0.9247
# Epoch 100/100
# 1168/1168 [==============================] - 0s 127us/step - loss: 0.2160 - acc: 0.8981 - val_loss: 0.2675 - val_acc: 0.9247

# %%
# Plot Precisión

plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('Precisión')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['Train', 'Test'], loc='lower right')
plt.show()

# Plot Pérdida

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Pérdida')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper right')
plt.show()
